# %%
# === MULTI-CURRENCY PROFIT-ONLY TRADING BOT (MT5 + Python) ===

import MetaTrader5 as mt5
import pandas as pd
import numpy as np
import talib
import time

# === CONFIG ===
SYMBOLS = ["XAUUSD", "EURUSD", "GBPUSD", "USDJPY"]
TIMEFRAME = mt5.TIMEFRAME_M15
LOT_SIZE = 0.1
MIN_PROFIT_USD = 1  # close trade when profit >= $1

# === INIT ===
if not mt5.initialize():
    raise RuntimeError(f"MT5 initialize() failed: {mt5.last_error()}")

account = mt5.account_info()
if account is None:
    raise RuntimeError(f"MT5 account_info() failed: {mt5.last_error()}")

for symbol in SYMBOLS:
    info = mt5.symbol_info(symbol)
    if info is None:
        raise RuntimeError(f"Symbol {symbol} not found")
    if not info.visible:
        mt5.symbol_select(symbol, True)

# === HELPER: Get recent candles ===
def get_data(symbol, timeframe, n=100):
    rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, n)
    if rates is None or len(rates) == 0:
        raise RuntimeError(f"Failed to retrieve market data for {symbol}: {mt5.last_error()}")
    df = pd.DataFrame(rates)
    df['time'] = pd.to_datetime(df['time'], unit='s')
    return df

# === HELPER: Entry Signal (Engulfing + RSI < 40 Buy or RSI > 60 Sell) ===
def get_trade_signal(df):
    close = df['close'].astype(float).values
    open_ = df['open'].astype(float).values
    high = df['high'].astype(float).values
    low = df['low'].astype(float).values

    rsi = talib.RSI(close, timeperiod=14)
    engulf = talib.CDLENGULFING(open_, high, low, close)

    if len(rsi) == 0 or len(engulf) == 0:
        return None

    print(f"Last RSI: {rsi[-1]:.2f}, Last Engulfing: {engulf[-1]}")

    if engulf[-1] > 0 and rsi[-1] < 40:
        print("Buy signal detected")
        return "buy"
    elif engulf[-1] < 0 and rsi[-1] > 60:
        print("Sell signal detected")
        return "sell"
    else:
        print("No valid signal at this time.")
    return None

# === HELPER: Open Trade ===
def open_trade(symbol, direction):
    tick = mt5.symbol_info_tick(symbol)
    price = tick.ask if direction == "buy" else tick.bid
    order_type = mt5.ORDER_TYPE_BUY if direction == "buy" else mt5.ORDER_TYPE_SELL

    request = {
        "action": mt5.TRADE_ACTION_DEAL,
        "symbol": symbol,
        "volume": LOT_SIZE,
        "type": order_type,
        "price": price,
        "deviation": 20,
        "magic": 10001,
        "comment": "profit_only_trade",
        "type_time": mt5.ORDER_TIME_GTC,
        "type_filling": mt5.ORDER_FILLING_IOC,
    }
    result = mt5.order_send(request)
    if result.retcode == mt5.TRADE_RETCODE_DONE:
        print(f"Opened {direction.upper()} for {symbol} at {price}")
    else:
        print(f"Order failed for {symbol}: {result.retcode} - {result.comment if hasattr(result, 'comment') else 'No comment'}")
        print(result._asdict())

# === HELPER: Close Trade if profit >= $1 ===
def check_and_close():
    for symbol in SYMBOLS:
        positions = mt5.positions_get(symbol=symbol)
        if positions:
            pos = positions[0]
            profit = pos.profit
            print(f"{symbol} position profit: ${profit:.2f}")
            if profit >= MIN_PROFIT_USD:
                close_type = mt5.ORDER_TYPE_SELL if pos.type == mt5.ORDER_TYPE_BUY else mt5.ORDER_TYPE_BUY
                price = mt5.symbol_info_tick(symbol).bid if pos.type == mt5.ORDER_TYPE_BUY else mt5.symbol_info_tick(symbol).ask
                close_req = {
                    "action": mt5.TRADE_ACTION_DEAL,
                    "symbol": symbol,
                    "volume": pos.volume,
                    "type": close_type,
                    "position": pos.ticket,
                    "price": price,
                    "deviation": 20,
                    "magic": 10001,
                    "comment": "close_in_profit",
                    "type_time": mt5.ORDER_TIME_GTC,
                    "type_filling": mt5.ORDER_FILLING_IOC,
                }
                result = mt5.order_send(close_req)
                if result.retcode == mt5.TRADE_RETCODE_DONE:
                    print(f"Closed {symbol} in profit: ${profit:.2f}")
                else:
                    print(f"Close failed for {symbol}: {result.retcode}")

# === MAIN LOOP ===
print("Running multi-currency profit-only bot...")
try:
    while True:
        check_and_close()
        time.sleep(2)

        for symbol in SYMBOLS:
            if not any(pos.symbol == symbol for pos in mt5.positions_get() or []):
                df = get_data(symbol, TIMEFRAME, 100)
                signal = get_trade_signal(df)
                if signal:
                    open_trade(symbol, signal)

        time.sleep(60)  # wait 1 min before checking again
except KeyboardInterrupt:
    print("Stopped by user")
finally:
    mt5.shutdown()
# Out:
# Running multi-currency profit-only bot...
# Last RSI: 67.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.81, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.33, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.61, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.52, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.41, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.22, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.97, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.16, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 63.88, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.08, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.40, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 63.58, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.40, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.02, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 63.79, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.41, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.43, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.18, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.07, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.98, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.09, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.51, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.93, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.46, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.38, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.37, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.60, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.70, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.60, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.52, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.82, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.43, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.66, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.82, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.85, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.02, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.41, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.13, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.00, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.68, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.26, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.29, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.70, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.24, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.50, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.81, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.11, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.63, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.81, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.66, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.76, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.39, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 65.59, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.24, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.82, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.75, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.00, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.16, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.97, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.64, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.76, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.24, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.39, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.76, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.78, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.46, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.36, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 41.70, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.68, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.42, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 44.20, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.09, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.78, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.15, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.42, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 41.90, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.96, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.99, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.15, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.58, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.55, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.05, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.97, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.27, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.03, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.56, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.88, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.04, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 44.43, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.38, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.12, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.02, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.47, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.02, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.47, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.02, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.47, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.02, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.47, Last Engulfing: 0
# No valid signal at this time.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 128
#     126 for symbol in SYMBOLS:
#     127     if not any(pos.symbol == symbol for pos in mt5.positions_get() or []):
# --> 128         df = get_data(symbol, TIMEFRAME, 100)
#     129         signal = get_trade_signal(df)
#     130         if signal:
#
# Cell In[1], line 34, in get_data(symbol, timeframe, n)
#      32 rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, n)
#      33 if rates is None or len(rates) == 0:
# ---> 34     raise RuntimeError(f"Failed to retrieve market data for {symbol}: {mt5.last_error()}")
#      35 df = pd.DataFrame(rates)
#      36 df['time'] = pd.to_datetime(df['time'], unit='s')
#
# RuntimeError: Failed to retrieve market data for XAUUSD: (-10001, 'IPC send failed')
