# %%
# === MULTI-CURRENCY PROFIT-ONLY TRADING BOT (MT5 + Python) ===

import MetaTrader5 as mt5
import pandas as pd
import numpy as np
import talib
import time

# === CONFIG ===
SYMBOLS = [
    "XAUUSD", "EURUSD", "GBPUSD", "USDJPY", "AUDUSD",
    "USDCAD", "NZDUSD", "USDCHF", "EURJPY", "GBPJPY",
    "EURGBP", "CADJPY", "CHFJPY", "AUDJPY", "EURNZD"
]
TIMEFRAME = mt5.TIMEFRAME_M15
LOT_SIZE = 0.1
MIN_PROFIT_USD = 1  # close trade when profit >= $1

# === INIT ===
if not mt5.initialize():
    raise RuntimeError(f"MT5 initialize() failed: {mt5.last_error()}")

account = mt5.account_info()
if account is None:
    raise RuntimeError(f"MT5 account_info() failed: {mt5.last_error()}")

for symbol in SYMBOLS:
    info = mt5.symbol_info(symbol)
    if info is None:
        raise RuntimeError(f"Symbol {symbol} not found")
    if not info.visible:
        mt5.symbol_select(symbol, True)

# === HELPER: Get recent candles ===
def get_data(symbol, timeframe, n=100):
    rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, n)
    if rates is None or len(rates) == 0:
        raise RuntimeError(f"Failed to retrieve market data for {symbol}: {mt5.last_error()}")
    df = pd.DataFrame(rates)
    df['time'] = pd.to_datetime(df['time'], unit='s')
    return df

# === HELPER: Entry Signal (Engulfing + RSI < 40 Buy or RSI > 60 Sell) ===
def get_trade_signal(df):
    close = df['close'].astype(float).values
    open_ = df['open'].astype(float).values
    high = df['high'].astype(float).values
    low = df['low'].astype(float).values

    rsi = talib.RSI(close, timeperiod=14)
    engulf = talib.CDLENGULFING(open_, high, low, close)

    if len(rsi) == 0 or len(engulf) == 0:
        return None

    print(f"Last RSI: {rsi[-1]:.2f}, Last Engulfing: {engulf[-1]}")

    if engulf[-1] > 0 and rsi[-1] < 40:
        print("Buy signal detected")
        return "buy"
    elif engulf[-1] < 0 and rsi[-1] > 60:
        print("Sell signal detected")
        return "sell"
    else:
        print("No valid signal at this time.")
    return None

# === HELPER: Open Trade ===
def open_trade(symbol, direction):
    tick = mt5.symbol_info_tick(symbol)
    price = tick.ask if direction == "buy" else tick.bid
    order_type = mt5.ORDER_TYPE_BUY if direction == "buy" else mt5.ORDER_TYPE_SELL

    request = {
        "action": mt5.TRADE_ACTION_DEAL,
        "symbol": symbol,
        "volume": LOT_SIZE,
        "type": order_type,
        "price": price,
        "deviation": 20,
        "magic": 10001,
        "comment": "profit_only_trade",
        "type_time": mt5.ORDER_TIME_GTC,
        "type_filling": mt5.ORDER_FILLING_IOC,
    }
    result = mt5.order_send(request)
    if result.retcode == mt5.TRADE_RETCODE_DONE:
        print(f"Opened {direction.upper()} for {symbol} at {price}")
    else:
        print(f"Order failed for {symbol}: {result.retcode} - {result.comment if hasattr(result, 'comment') else 'No comment'}")
        print(result._asdict())

# === HELPER: Close Trade if profit >= $1 ===
def check_and_close():
    for symbol in SYMBOLS:
        positions = mt5.positions_get(symbol=symbol)
        if positions:
            pos = positions[0]
            profit = pos.profit
            print(f"{symbol} position profit: ${profit:.2f}")
            if profit >= MIN_PROFIT_USD:
                close_type = mt5.ORDER_TYPE_SELL if pos.type == mt5.ORDER_TYPE_BUY else mt5.ORDER_TYPE_BUY
                price = mt5.symbol_info_tick(symbol).bid if pos.type == mt5.ORDER_TYPE_BUY else mt5.symbol_info_tick(symbol).ask
                close_req = {
                    "action": mt5.TRADE_ACTION_DEAL,
                    "symbol": symbol,
                    "volume": pos.volume,
                    "type": close_type,
                    "position": pos.ticket,
                    "price": price,
                    "deviation": 20,
                    "magic": 10001,
                    "comment": "close_in_profit",
                    "type_time": mt5.ORDER_TIME_GTC,
                    "type_filling": mt5.ORDER_FILLING_IOC,
                }
                result = mt5.order_send(close_req)
                if result.retcode == mt5.TRADE_RETCODE_DONE:
                    print(f"Closed {symbol} in profit: ${profit:.2f}")
                else:
                    print(f"Close failed for {symbol}: {result.retcode}")

# === MAIN LOOP ===
print("Running multi-currency profit-only bot...")
try:
    while True:
        check_and_close()
        time.sleep(2)

        for symbol in SYMBOLS:
            if not any(pos.symbol == symbol for pos in mt5.positions_get() or []):
                df = get_data(symbol, TIMEFRAME, 100)
                signal = get_trade_signal(df)
                if signal:
                    open_trade(symbol, signal)

        time.sleep(60)  # wait 1 min before checking again
except KeyboardInterrupt:
    print("Stopped by user")
finally:
    mt5.shutdown()
# Out:
# Running multi-currency profit-only bot...
# Last RSI: 66.24, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.66, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 37.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.30, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 39.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.11, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.57, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.79, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.96, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.55, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 63.51, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.67, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.83, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.27, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 38.51, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.11, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.57, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.76, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.89, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.59, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.78, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 63.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.82, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.22, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.95, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.67, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 38.75, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.21, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.00, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.64, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.76, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.02, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.78, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.15, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.31, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 37.67, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.89, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 39.37, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.55, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 53.40, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.14, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.33, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.55, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.31, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.83, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.60, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.17, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.37, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.15, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.29, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 39.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 41.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.70, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 51.11, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.83, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.56, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.95, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.72, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.31, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.16, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.13, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.33, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.29, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 38.99, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 40.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.89, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.70, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.68, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.85, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.61, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.76, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.18, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.24, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 37.67, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.55, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 39.63, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.89, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.43, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.55, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.52, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.56, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.76, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.30, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.34, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.98, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.59, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.01, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 38.75, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.93, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.57, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.44, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.17, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 55.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.05, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.52, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.14, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.30, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.05, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.31, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.24, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 37.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.82, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 39.50, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.33, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.76, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.79, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 54.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.39, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.18, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.02, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.18, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.64, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 37.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.55, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 40.15, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.26, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.97, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.01, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.79, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 54.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.84, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.67, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.09, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.82, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.18, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.36, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.02, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.63, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 39.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.61, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 52.22, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.72, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.98, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 54.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.39, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.56, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.97, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.95, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.21, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.62, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.40, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 35.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.82, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 38.51, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.61, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 52.79, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.98, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 55.05, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.61, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 58.39, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.09, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.38, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.36, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 35.57, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.82, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 38.63, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.06, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 53.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.56, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.59, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 54.99, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.21, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 58.09, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.00, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.00, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 35.79, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.14, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 39.37, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.70, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 53.58, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.72, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.48, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 54.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.78, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.56, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 58.00, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 65.91, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.33, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.01, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 35.45, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.06, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 39.37, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.23, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.20, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 57.52, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.38, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.23, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.95, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.00, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.67, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.88, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 38.08, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.07, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 41.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.80, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.34, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.51, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.88, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 57.22, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.08, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.53, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 66.82, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.84, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.80, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.78, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 38.46, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 41.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.62, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.97, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.50, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 51.40, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.21, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 57.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 45.45, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.05, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.40, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.59, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.17, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.63, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 34.91, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 38.62, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.33, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.85, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 51.59, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.07, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.63, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.68, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 41.96, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.78, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 33.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.51, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.70, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.36, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.60, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 53.40, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.12, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.32, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 58.93, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.30, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.12, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 41.64, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.83, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 33.70, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.36, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.51, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 53.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.29, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 55.22, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.98, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 59.47, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.25, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 44.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.16, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.01, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 34.02, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.64, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.51, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.51, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.13, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.08, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 52.69, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.41, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.05, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.60, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 58.57, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.07, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.36, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.20, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 33.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.70, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.34, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 51.59, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.45, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.27, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 58.98, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.70, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.58, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.17, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 33.70, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.48, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.27, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.60, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.08, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 46.99, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 49.85, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.27, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.50, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.49, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 58.38, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.05, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.17, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.63, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 33.17, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 51.29, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.91, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 47.44, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.23, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.27, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.61, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.38, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 58.98, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 67.62, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.69, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.32, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 33.91, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.88, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 50.01, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.06, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.26, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.04, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.29, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.51, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.49, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 58.52, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.39, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 45.08, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.31, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 52.97, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 35.87, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.74, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.21, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.28, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.31, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 51.78, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.21, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.18, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 58.66, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 68.78, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.35, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 42.76, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.92, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 35.24, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.21, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.27, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 49.21, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.98, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.23, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.42, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.00, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 58.25, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.02, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.47, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.08, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.62, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.64, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.23, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.12, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 57.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.02, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.47, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.08, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.62, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.64, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.23, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.12, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 57.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.02, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.47, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.08, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.62, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.64, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.23, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.12, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 57.49, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 69.02, Last Engulfing: 100
# No valid signal at this time.
# Last RSI: 43.65, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 43.10, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 53.47, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.08, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.62, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 36.86, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.73, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.54, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 48.64, Last Engulfing: -100
# No valid signal at this time.
# Last RSI: 50.23, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 54.19, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 56.12, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 44.77, Last Engulfing: 0
# No valid signal at this time.
# Last RSI: 57.49, Last Engulfing: 0
# No valid signal at this time.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 132
#     130 for symbol in SYMBOLS:
#     131     if not any(pos.symbol == symbol for pos in mt5.positions_get() or []):
# --> 132         df = get_data(symbol, TIMEFRAME, 100)
#     133         signal = get_trade_signal(df)
#     134         if signal:
#
# Cell In[1], line 38, in get_data(symbol, timeframe, n)
#      36 rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, n)
#      37 if rates is None or len(rates) == 0:
# ---> 38     raise RuntimeError(f"Failed to retrieve market data for {symbol}: {mt5.last_error()}")
#      39 df = pd.DataFrame(rates)
#      40 df['time'] = pd.to_datetime(df['time'], unit='s')
#
# RuntimeError: Failed to retrieve market data for XAUUSD: (-10001, 'IPC send failed')
