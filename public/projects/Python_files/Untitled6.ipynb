# %%
# === MULTI-CURRENCY PROFIT-ONLY TRADING BOT (MT5 + Python) ===

import MetaTrader5 as mt5
import pandas as pd
import numpy as np
import talib
import time

# === CONFIG ===
SYMBOLS = [
    "XAUUSD", "EURUSD", "GBPUSD", "USDJPY", "AUDUSD",
    "USDCAD", "NZDUSD", "USDCHF", "EURJPY", "GBPJPY",
    "EURGBP", "CADJPY", "CHFJPY", "AUDJPY", "EURNZD"
]
TIMEFRAME = mt5.TIMEFRAME_M15
LOT_SIZE = 0.1
MIN_PROFIT_USD = 1  # close trade when profit >= $1
MAX_TRADES = 5  # maximum concurrent trades

# === INIT ===
if not mt5.initialize():
    raise RuntimeError(f"MT5 initialize() failed: {mt5.last_error()}")

account = mt5.account_info()
if account is None:
    raise RuntimeError(f"MT5 account_info() failed: {mt5.last_error()}")

for symbol in SYMBOLS:
    info = mt5.symbol_info(symbol)
    if info is None:
        raise RuntimeError(f"Symbol {symbol} not found")
    if not info.visible:
        mt5.symbol_select(symbol, True)

# === HELPER: Get recent candles ===
def get_data(symbol, timeframe, n=100):
    rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, n)
    if rates is None or len(rates) == 0:
        raise RuntimeError(f"Failed to retrieve market data for {symbol}: {mt5.last_error()}")
    df = pd.DataFrame(rates)
    df['time'] = pd.to_datetime(df['time'], unit='s')
    return df

# === HELPER: Entry Signal (Custom Strategy Per Symbol) ===
def get_trade_signal(df, symbol):
    close = df['close'].astype(float).values
    open_ = df['open'].astype(float).values
    high = df['high'].astype(float).values
    low = df['low'].astype(float).values

    rsi = talib.RSI(close, timeperiod=14)
    engulf = talib.CDLENGULFING(open_, high, low, close)

    if len(rsi) == 0 or len(engulf) == 0:
        return None

    last_rsi = rsi[-1]
    last_engulf = engulf[-1]
    print(f"{symbol} - RSI: {last_rsi:.2f}, Engulfing: {last_engulf}")

    # Custom strategy per symbol
    if symbol == "XAUUSD" and last_engulf > 0 and last_rsi < 45:
        return "buy"
    elif symbol == "XAUUSD" and last_engulf < 0 and last_rsi > 55:
        return "sell"
    elif symbol == "EURUSD" and last_engulf > 0 and last_rsi < 35:
        return "buy"
    elif symbol == "EURUSD" and last_engulf < 0 and last_rsi > 65:
        return "sell"
    elif last_engulf > 0 and last_rsi < 40:
        return "buy"
    elif last_engulf < 0 and last_rsi > 60:
        return "sell"
    return None

# === HELPER: Open Trade ===
def open_trade(symbol, direction):
    tick = mt5.symbol_info_tick(symbol)
    price = tick.ask if direction == "buy" else tick.bid
    order_type = mt5.ORDER_TYPE_BUY if direction == "buy" else mt5.ORDER_TYPE_SELL

    request = {
        "action": mt5.TRADE_ACTION_DEAL,
        "symbol": symbol,
        "volume": LOT_SIZE,
        "type": order_type,
        "price": price,
        "deviation": 20,
        "magic": 10001,
        "comment": "profit_only_trade",
        "type_time": mt5.ORDER_TIME_GTC,
        "type_filling": mt5.ORDER_FILLING_IOC,
    }
    result = mt5.order_send(request)
    if result.retcode == mt5.TRADE_RETCODE_DONE:
        print(f"Opened {direction.upper()} for {symbol} at {price}")
    else:
        print(f"Order failed for {symbol}: {result.retcode} - {getattr(result, 'comment', 'No comment')}")
        print(result._asdict())

# === HELPER: Close Trade if profit >= $1 ===
def check_and_close():
    for symbol in SYMBOLS:
        positions = mt5.positions_get(symbol=symbol)
        if positions:
            pos = positions[0]
            profit = pos.profit
            print(f"{symbol} position profit: ${profit:.2f}")
            if profit >= MIN_PROFIT_USD:
                close_type = mt5.ORDER_TYPE_SELL if pos.type == mt5.ORDER_TYPE_BUY else mt5.ORDER_TYPE_BUY
                price = mt5.symbol_info_tick(symbol).bid if pos.type == mt5.ORDER_TYPE_BUY else mt5.symbol_info_tick(symbol).ask
                close_req = {
                    "action": mt5.TRADE_ACTION_DEAL,
                    "symbol": symbol,
                    "volume": pos.volume,
                    "type": close_type,
                    "position": pos.ticket,
                    "price": price,
                    "deviation": 20,
                    "magic": 10001,
                    "comment": "close_in_profit",
                    "type_time": mt5.ORDER_TIME_GTC,
                    "type_filling": mt5.ORDER_FILLING_IOC,
                }
                result = mt5.order_send(close_req)
                if result.retcode == mt5.TRADE_RETCODE_DONE:
                    print(f"Closed {symbol} in profit: ${profit:.2f}")
                else:
                    print(f"Close failed for {symbol}: {result.retcode}")

# === MAIN LOOP ===
print("Running multi-currency profit-only bot...")
try:
    while True:
        check_and_close()
        time.sleep(2)

        current_trades = len(mt5.positions_get() or [])
        if current_trades >= MAX_TRADES:
            print(f"Max trades ({MAX_TRADES}) reached. Waiting to open new trades.")
            time.sleep(60)
            continue

        for symbol in SYMBOLS:
            if not any(pos.symbol == symbol for pos in mt5.positions_get() or []):
                df = get_data(symbol, TIMEFRAME, 100)
                signal = get_trade_signal(df, symbol)
                if signal:
                    open_trade(symbol, signal)

        time.sleep(60)  # wait 1 min before checking again
except KeyboardInterrupt:
    print("Stopped by user")
finally:
    mt5.shutdown()
# Out:
# Running multi-currency profit-only bot...
# XAUUSD - RSI: 66.70, Engulfing: 0
# EURUSD - RSI: 44.92, Engulfing: 0
# GBPUSD - RSI: 43.73, Engulfing: 0
# USDJPY - RSI: 52.73, Engulfing: 0
# AUDUSD - RSI: 38.27, Engulfing: 0
# USDCAD - RSI: 49.35, Engulfing: 0
# NZDUSD - RSI: 41.35, Engulfing: 0
# USDCHF - RSI: 46.53, Engulfing: 0
# EURJPY - RSI: 49.03, Engulfing: 0
# GBPJPY - RSI: 48.45, Engulfing: -100
# EURGBP - RSI: 51.21, Engulfing: 0
# CADJPY - RSI: 53.21, Engulfing: 0
# CHFJPY - RSI: 57.79, Engulfing: 0
# AUDJPY - RSI: 45.32, Engulfing: 0
# EURNZD - RSI: 54.16, Engulfing: 0
# XAUUSD - RSI: 67.22, Engulfing: 0
# EURUSD - RSI: 44.51, Engulfing: 0
# GBPUSD - RSI: 43.03, Engulfing: 0
# USDJPY - RSI: 52.63, Engulfing: 0
# AUDUSD - RSI: 34.80, Engulfing: 0
# USDCAD - RSI: 49.92, Engulfing: 0
# NZDUSD - RSI: 38.23, Engulfing: 0
# USDCHF - RSI: 47.33, Engulfing: 0
# EURJPY - RSI: 48.42, Engulfing: 0
# GBPJPY - RSI: 47.39, Engulfing: -100
# EURGBP - RSI: 51.78, Engulfing: 0
# CADJPY - RSI: 53.07, Engulfing: 0
# CHFJPY - RSI: 56.40, Engulfing: 0
# AUDJPY - RSI: 43.66, Engulfing: -100
# EURNZD - RSI: 57.13, Engulfing: 0
# XAUUSD - RSI: 67.18, Engulfing: 0
# EURUSD - RSI: 44.28, Engulfing: 0
# GBPUSD - RSI: 41.96, Engulfing: 0
# USDJPY - RSI: 52.92, Engulfing: 0
# AUDUSD - RSI: 33.17, Engulfing: 0
# USDCAD - RSI: 50.06, Engulfing: 0
# NZDUSD - RSI: 36.51, Engulfing: 0
# USDCHF - RSI: 47.88, Engulfing: 0
# EURJPY - RSI: 48.60, Engulfing: 0
# GBPJPY - RSI: 47.08, Engulfing: -100
# EURGBP - RSI: 53.22, Engulfing: 0
# CADJPY - RSI: 53.21, Engulfing: 0
# CHFJPY - RSI: 56.58, Engulfing: 0
# AUDJPY - RSI: 42.70, Engulfing: -100
# EURNZD - RSI: 58.71, Engulfing: 0
# XAUUSD - RSI: 67.37, Engulfing: 0
# EURUSD - RSI: 44.12, Engulfing: 0
# GBPUSD - RSI: 41.64, Engulfing: 0
# USDJPY - RSI: 52.68, Engulfing: 0
# AUDUSD - RSI: 33.70, Engulfing: 0
# USDCAD - RSI: 49.49, Engulfing: 0
# NZDUSD - RSI: 36.04, Engulfing: 0
# USDCHF - RSI: 48.92, Engulfing: 0
# EURJPY - RSI: 48.12, Engulfing: 0
# GBPJPY - RSI: 46.38, Engulfing: -100
# EURGBP - RSI: 53.57, Engulfing: 0
# CADJPY - RSI: 53.14, Engulfing: 0
# CHFJPY - RSI: 55.00, Engulfing: 0
# AUDJPY - RSI: 42.70, Engulfing: -100
# EURNZD - RSI: 59.38, Engulfing: 0
# XAUUSD - RSI: 68.91, Engulfing: 100
# EURUSD - RSI: 44.04, Engulfing: 0
# GBPUSD - RSI: 42.16, Engulfing: 0
# USDJPY - RSI: 52.49, Engulfing: 0
# AUDUSD - RSI: 33.91, Engulfing: 0
# USDCAD - RSI: 49.64, Engulfing: 0
# NZDUSD - RSI: 36.51, Engulfing: 0
# USDCHF - RSI: 50.11, Engulfing: 0
# EURJPY - RSI: 47.71, Engulfing: 0
# GBPJPY - RSI: 46.47, Engulfing: -100
# EURGBP - RSI: 52.51, Engulfing: 0
# CADJPY - RSI: 52.92, Engulfing: 0
# CHFJPY - RSI: 53.10, Engulfing: 0
# AUDJPY - RSI: 42.87, Engulfing: -100
# EURNZD - RSI: 58.57, Engulfing: 0
# XAUUSD - RSI: 67.82, Engulfing: 100
# EURUSD - RSI: 43.81, Engulfing: 0
# GBPUSD - RSI: 42.49, Engulfing: 0
# USDJPY - RSI: 52.01, Engulfing: 0
# AUDUSD - RSI: 33.28, Engulfing: 0
# USDCAD - RSI: 49.35, Engulfing: 0
# NZDUSD - RSI: 36.16, Engulfing: 0
# USDCHF - RSI: 50.60, Engulfing: 0
# EURJPY - RSI: 47.08, Engulfing: 0
# GBPJPY - RSI: 46.29, Engulfing: -100
# EURGBP - RSI: 51.78, Engulfing: 0
# CADJPY - RSI: 52.49, Engulfing: 0
# CHFJPY - RSI: 52.40, Engulfing: 0
# AUDJPY - RSI: 42.16, Engulfing: -100
# EURNZD - RSI: 59.07, Engulfing: 0
# XAUUSD - RSI: 67.83, Engulfing: 100
# EURUSD - RSI: 44.12, Engulfing: 0
# GBPUSD - RSI: 43.38, Engulfing: 0
# USDJPY - RSI: 51.96, Engulfing: 0
# AUDUSD - RSI: 34.24, Engulfing: 0
# USDCAD - RSI: 50.06, Engulfing: 0
# NZDUSD - RSI: 36.74, Engulfing: 0
# USDCHF - RSI: 50.31, Engulfing: 0
# EURJPY - RSI: 47.25, Engulfing: 0
# GBPJPY - RSI: 47.17, Engulfing: -100
# EURGBP - RSI: 50.23, Engulfing: 0
# CADJPY - RSI: 52.13, Engulfing: 0
# CHFJPY - RSI: 52.50, Engulfing: 0
# AUDJPY - RSI: 42.93, Engulfing: -100
# EURNZD - RSI: 58.71, Engulfing: 0
# XAUUSD - RSI: 68.10, Engulfing: 100
# EURUSD - RSI: 43.81, Engulfing: 0
# GBPUSD - RSI: 42.76, Engulfing: 0
# USDJPY - RSI: 52.58, Engulfing: 0
# AUDUSD - RSI: 33.17, Engulfing: 0
# USDCAD - RSI: 51.29, Engulfing: 0
# NZDUSD - RSI: 36.16, Engulfing: 0
# USDCHF - RSI: 49.91, Engulfing: 0
# EURJPY - RSI: 47.59, Engulfing: 0
# GBPJPY - RSI: 47.39, Engulfing: -100
# EURGBP - RSI: 50.82, Engulfing: 0
# CADJPY - RSI: 52.27, Engulfing: 0
# CHFJPY - RSI: 53.61, Engulfing: 0
# AUDJPY - RSI: 42.38, Engulfing: -100
# EURNZD - RSI: 59.07, Engulfing: 0
# XAUUSD - RSI: 67.63, Engulfing: 100
# EURUSD - RSI: 43.35, Engulfing: 0
# GBPUSD - RSI: 42.76, Engulfing: 0
# USDJPY - RSI: 53.27, Engulfing: 0
# AUDUSD - RSI: 33.91, Engulfing: 0
# USDCAD - RSI: 51.02, Engulfing: 0
# NZDUSD - RSI: 36.04, Engulfing: 0
# USDCHF - RSI: 50.01, Engulfing: 0
# EURJPY - RSI: 48.12, Engulfing: 0
# GBPJPY - RSI: 48.31, Engulfing: -100
# EURGBP - RSI: 50.04, Engulfing: 0
# CADJPY - RSI: 53.14, Engulfing: 0
# CHFJPY - RSI: 54.35, Engulfing: 0
# AUDJPY - RSI: 43.37, Engulfing: -100
# EURNZD - RSI: 58.43, Engulfing: 0
# XAUUSD - RSI: 68.17, Engulfing: 100
# EURUSD - RSI: 44.67, Engulfing: 0
# GBPUSD - RSI: 43.24, Engulfing: 0
# USDJPY - RSI: 53.17, Engulfing: 0
# AUDUSD - RSI: 35.03, Engulfing: 0
# USDCAD - RSI: 50.06, Engulfing: 0
# NZDUSD - RSI: 36.74, Engulfing: 0
# USDCHF - RSI: 49.61, Engulfing: 0
# EURJPY - RSI: 49.34, Engulfing: 0
# GBPJPY - RSI: 48.55, Engulfing: -100
# EURGBP - RSI: 51.78, Engulfing: 0
# CADJPY - RSI: 53.43, Engulfing: 0
# CHFJPY - RSI: 54.46, Engulfing: 0
# AUDJPY - RSI: 44.18, Engulfing: 0
# EURNZD - RSI: 59.02, Engulfing: 0
# XAUUSD - RSI: 68.76, Engulfing: 100
# EURUSD - RSI: 43.35, Engulfing: 0
# GBPUSD - RSI: 42.76, Engulfing: 0
# USDJPY - RSI: 53.77, Engulfing: 0
# AUDUSD - RSI: 35.03, Engulfing: 0
# USDCAD - RSI: 49.35, Engulfing: 0
# NZDUSD - RSI: 36.27, Engulfing: 0
# USDCHF - RSI: 48.63, Engulfing: 0
# EURJPY - RSI: 48.67, Engulfing: 0
# GBPJPY - RSI: 48.69, Engulfing: -100
# EURGBP - RSI: 50.43, Engulfing: 0
# CADJPY - RSI: 54.19, Engulfing: 0
# CHFJPY - RSI: 56.58, Engulfing: 0
# AUDJPY - RSI: 44.71, Engulfing: 0
# EURNZD - RSI: 58.20, Engulfing: 0
# XAUUSD - RSI: 69.02, Engulfing: 100
# EURUSD - RSI: 43.65, Engulfing: 0
# GBPUSD - RSI: 43.10, Engulfing: 0
# USDJPY - RSI: 53.47, Engulfing: 0
# AUDUSD - RSI: 36.08, Engulfing: 0
# USDCAD - RSI: 48.62, Engulfing: 0
# NZDUSD - RSI: 36.86, Engulfing: 0
# USDCHF - RSI: 48.73, Engulfing: 0
# EURJPY - RSI: 48.54, Engulfing: 0
# GBPJPY - RSI: 48.64, Engulfing: -100
# EURGBP - RSI: 50.23, Engulfing: 0
# CADJPY - RSI: 54.19, Engulfing: 0
# CHFJPY - RSI: 56.12, Engulfing: 0
# AUDJPY - RSI: 44.77, Engulfing: 0
# EURNZD - RSI: 57.49, Engulfing: 0
# XAUUSD - RSI: 69.02, Engulfing: 100
# EURUSD - RSI: 43.65, Engulfing: 0
# GBPUSD - RSI: 43.10, Engulfing: 0
# USDJPY - RSI: 53.47, Engulfing: 0
# AUDUSD - RSI: 36.08, Engulfing: 0
# USDCAD - RSI: 48.62, Engulfing: 0
# NZDUSD - RSI: 36.86, Engulfing: 0
# USDCHF - RSI: 48.73, Engulfing: 0
# EURJPY - RSI: 48.54, Engulfing: 0
# GBPJPY - RSI: 48.64, Engulfing: -100
# EURGBP - RSI: 50.23, Engulfing: 0
# CADJPY - RSI: 54.19, Engulfing: 0
# CHFJPY - RSI: 56.12, Engulfing: 0
# AUDJPY - RSI: 44.77, Engulfing: 0
# EURNZD - RSI: 57.49, Engulfing: 0
# XAUUSD - RSI: 69.02, Engulfing: 100
# EURUSD - RSI: 43.65, Engulfing: 0
# GBPUSD - RSI: 43.10, Engulfing: 0
# USDJPY - RSI: 53.47, Engulfing: 0
# AUDUSD - RSI: 36.08, Engulfing: 0
# USDCAD - RSI: 48.62, Engulfing: 0
# NZDUSD - RSI: 36.86, Engulfing: 0
# USDCHF - RSI: 48.73, Engulfing: 0
# EURJPY - RSI: 48.54, Engulfing: 0
# GBPJPY - RSI: 48.64, Engulfing: -100
# EURGBP - RSI: 50.23, Engulfing: 0
# CADJPY - RSI: 54.19, Engulfing: 0
# CHFJPY - RSI: 56.12, Engulfing: 0
# AUDJPY - RSI: 44.77, Engulfing: 0
# EURNZD - RSI: 57.49, Engulfing: 0
# XAUUSD - RSI: 69.02, Engulfing: 100
# EURUSD - RSI: 43.65, Engulfing: 0
# GBPUSD - RSI: 43.10, Engulfing: 0
# USDJPY - RSI: 53.47, Engulfing: 0
# AUDUSD - RSI: 36.08, Engulfing: 0
# USDCAD - RSI: 48.62, Engulfing: 0
# NZDUSD - RSI: 36.86, Engulfing: 0
# USDCHF - RSI: 48.73, Engulfing: 0
# EURJPY - RSI: 48.54, Engulfing: 0
# GBPJPY - RSI: 48.64, Engulfing: -100
# EURGBP - RSI: 50.23, Engulfing: 0
# CADJPY - RSI: 54.19, Engulfing: 0
# CHFJPY - RSI: 56.12, Engulfing: 0
# AUDJPY - RSI: 44.77, Engulfing: 0
# EURNZD - RSI: 57.49, Engulfing: 0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 146
#     144 for symbol in SYMBOLS:
#     145     if not any(pos.symbol == symbol for pos in mt5.positions_get() or []):
# --> 146         df = get_data(symbol, TIMEFRAME, 100)
#     147         signal = get_trade_signal(df, symbol)
#     148         if signal:
#
# Cell In[16], line 39, in get_data(symbol, timeframe, n)
#      37 rates = mt5.copy_rates_from_pos(symbol, timeframe, 0, n)
#      38 if rates is None or len(rates) == 0:
# ---> 39     raise RuntimeError(f"Failed to retrieve market data for {symbol}: {mt5.last_error()}")
#      40 df = pd.DataFrame(rates)
#      41 df['time'] = pd.to_datetime(df['time'], unit='s')
#
# RuntimeError: Failed to retrieve market data for XAUUSD: (-10001, 'IPC send failed')
